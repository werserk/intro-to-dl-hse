# %%
import torch
import numpy as np
from torch import nn
from torchvision.datasets import MNIST
from torchvision import transforms as T
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
transform = T.Compose([
    T.ToTensor(),
    T.Resize((32, 32)),
    T.Normalize([0.5], [0.5])
])

train_set = MNIST('/data', transform=transform, download=True, train=True)
test_set = MNIST('/data',  transform=transform, train=False)

# %% [markdown]
# ## 1. AutoEncoder
#
# ![](https://www.mdpi.com/information/information-10-00122/article_deploy/html/images/information-10-00122-g003.png)

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=5, stride=2, padding=2),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=5, stride=2, padding=2),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=5, stride=2, padding=2),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=4),
        )

    def forward(self, x):
        return self.net(x)


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=4),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 32, kernel_size=5, padding=2),
            nn.Upsample(scale_factor=2, mode='bilinear'),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 16, kernel_size=5, padding=2),
            nn.Upsample(scale_factor=2, mode='bilinear'),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 1, kernel_size=5, padding=2),
            nn.Upsample(scale_factor=2, mode='bilinear'),
        )

    def forward(self, x):
        return self.net(x)


class AutoEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()

    def encode(self, x):
        return self.encoder(x)

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        return self.decode(self.encode(x))

# %%
x = torch.randn(1, 1, 32, 32)
enc = Encoder()
dec = Decoder()

print(f'Encoder params: {sum(param.numel() for param in enc.parameters())}')
print(f'Decoder params: {sum(param.numel() for param in dec.parameters())}')
# Out:
# Encoder params: 195712
# Decoder params: 195585

# %%
z = enc(x)
z.shape
# Out:
# torch.Size([1, 128, 1, 1])

# %%
x_rec = dec(z)
x_rec.shape
# Out:
# torch.Size([1, 1, 32, 32])

# %%
plt.imshow((x.squeeze().detach() + 1) / 2, cmap='gray')

# %%
plt.imshow((x_rec.squeeze().detach() + 1) / 2, cmap='gray')

# %%
train_loader = DataLoader(train_set, batch_size=128, num_workers=4, pin_memory=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128, pin_memory=True, num_workers=4)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
ae = AutoEncoder().to(device)
optimizer = torch.optim.Adam(ae.parameters(), lr=3e-4)
criterion = nn.L1Loss()

# %%
num_epochs = 20

for epoch in range(1, num_epochs + 1):
    ae.train()
    train_loss = 0.0
    for images, _ in tqdm(train_loader, desc=f'Training {epoch}/{num_epochs}'):
        optimizer.zero_grad()
        images = images.to(device)
        reconstructed = ae(images)
        loss = criterion(reconstructed, images)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * images.shape[0]

    ae.eval()
    test_loss = 0.0
    with torch.inference_mode():
        for images, _ in tqdm(test_loader, desc=f'Testing {epoch}/{num_epochs}'):
            images = images.to(device)
            reconstructed = ae(images)
            loss = criterion(reconstructed, images)
            test_loss += loss.item() * images.shape[0]

    clear_output()
    train_loss /= len(train_set)
    test_loss /= len(test_set)
    print(f'Epoch {epoch}/{num_epochs}: train loss: {train_loss:.3f}, test loss: {test_loss:.3f}')
# Out:
# Epoch 20/20: train loss: 0.075, test loss: 0.076

# %%
image = test_set[71][0].unsqueeze(0)

# %%
plt.imshow((image.squeeze() + 1) / 2, cmap='gray')

# %%
ae = ae.to('cpu')

with torch.no_grad():
    rec_image = ae(image)

# %%
plt.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')

# %% [markdown]
# Autoencoder does not work as a generative model :(

# %%
from scipy.stats import norm

latents = []
for i in np.random.randint(0, len(test_set), 10):
    with torch.no_grad():
        image = test_set[i][0].unsqueeze(0)
        ae_latent = ae.encode(image.to(device))
        latents.append(ae_latent.squeeze().cpu().numpy())
plt.hist(np.concatenate(latents), bins=30)
plt.plot(np.linspace(-3, 3, 100), norm.pdf(np.linspace(-3, 3, 100) * 2) * 300)
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(6, 6))
plt.tight_layout()

for ax in axs.flatten():
    with torch.no_grad():
        z = torch.randn_like(z).to(device) * np.sqrt(6)
        rec_image = ae.decode(z)

    ax.imshow((rec_image.squeeze().cpu() + 1) / 2, cmap='gray')

plt.show()

# %% [markdown]
# ## 2. Variational Autoencoder
#
# ![](vae-gaussian-3780796575.png)
#
# $$
# \mathcal{L}_{VAE} = \underbrace{\mathbb{E}_{q_{\phi}(z|x)} \Big[\log p_{\theta}(x|z)\Big]}_{\text{reconstruction loss}} + \underbrace{KL\big(q_{\phi}(z|x) \big|\big|p(z)\big)}_{\text{latent regularization}}
# $$
#
# $$
# \log p_{\theta}(x|z) \propto \frac{1}{2} \Big\|x - \mu_{\theta}(z)\Big\|_2^2
# $$
#
# $$
# q_{\phi}(z|x) = \mathcal{N}\Big(z\Big|\mu_{\phi}(x), \text{diag}(\sigma_{\phi}^2(x))\Big) \Rightarrow KL\big(q_{\phi}(z|x) \big|\big|p(z)\big) = -\frac{d}{2} + \frac{1}{2}\sum_{i=1}^d \Big( -\log \sigma_i^2 + \sigma_i^2 + \mu_i^2\Big)
# $$

# %%
class VAEEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=5, stride=2, padding=2),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=5, stride=2, padding=2),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=5, stride=2, padding=2),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 2 * 128, kernel_size=4),
        )

    def forward(self, x):
        z = self.net(x)
        z_mu, z_log_sigma_sq = z[:, :128], z[:, 128:]
        return z_mu, z_log_sigma_sq


class VAEDecoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=4),
            nn.InstanceNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 32, kernel_size=5, padding=2),
            nn.Upsample(scale_factor=2, mode='bilinear'),
            nn.InstanceNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 16, kernel_size=5, padding=2),
            nn.Upsample(scale_factor=2, mode='bilinear'),
            nn.InstanceNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 1, kernel_size=5, padding=2),
            nn.Upsample(scale_factor=2, mode='bilinear'),
        )

    def forward(self, z):
        x_mu = self.net(z)
        return x_mu


class VAE(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = VAEEncoder()
        self.decoder = VAEDecoder()

    def encode(self, x):
        return self.encoder(x)

    def decode(self, z):
        return self.decoder(z)

    def reparameterize(self, mu, log_sigma_sq, eps):
        return mu + torch.exp(0.5 * log_sigma_sq) * eps

    def forward(self, x):
        z_mu, z_log_sigma_sq = self.encode(x)
        eps = torch.randn_like(z_mu)
        z = self.reparameterize(z_mu, z_log_sigma_sq, eps)
        x_mu = self.decode(z)
        return z_mu, z_log_sigma_sq, x_mu


class VAELoss(nn.Module):
    def forward(self, x, z_mu, z_log_sigma_sq, x_mu):
        z_sigma_sq = torch.exp(z_log_sigma_sq)
        rec_loss = ((x - x_mu).square()).sum() / x.shape[0]
        rec_loss = 0.5 * rec_loss

        kl_loss = (-1 + -z_log_sigma_sq + z_sigma_sq + z_mu.square()).sum() / x.shape[0]
        kl_loss = 0.5 * kl_loss
        return rec_loss + kl_loss, rec_loss, kl_loss

# %%
vae = VAE().to(device)
optimizer = torch.optim.Adam(vae.parameters(), lr=3e-4)
criterion = VAELoss()

# %%
num_epochs = 20

for epoch in range(1, num_epochs + 1):
    vae.train()
    train_loss, train_rec, train_kl = 0.0, 0.0, 0.0
    for images, _ in tqdm(train_loader, desc=f'Training {epoch}/{num_epochs}'):
        optimizer.zero_grad()
        images = images.to(device)
        out = vae(images)
        loss, rec, kl = criterion(images, *out)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * images.shape[0]
        train_rec += rec.item() * images.shape[0]
        train_kl += kl.item() * images.shape[0]

    vae.eval()
    test_loss, test_rec, test_kl = 0.0, 0.0, 0.0
    with torch.inference_mode():
        for images, _ in tqdm(test_loader, desc=f'Testing {epoch}/{num_epochs}'):
            images = images.to(device)
            out = vae(images)
            loss, rec, kl = criterion(images, *out)
            test_loss += loss.item() * images.shape[0]
            test_rec += rec.item() * images.shape[0]
            test_kl += kl.item() * images.shape[0]

    clear_output()
    train_loss /= len(train_set)
    test_loss /= len(test_set)
    train_rec /= len(train_set)
    test_rec /= len(test_set)
    train_kl /= len(train_set)
    test_kl /= len(test_set)

    print(
        f'Epoch {epoch}/{num_epochs}: train loss: {train_loss:.3f}, '
        f'train rec: {train_rec:.3f}, train kl: {train_kl:.3f}\n'
        f'\t\ttest loss: {test_loss:.3f}, test rec: {test_rec:.3f}, test kl: {test_kl:.3f}'
    )
# Out:
# Epoch 20/20: train loss: 43.479, train rec: 26.558, train kl: 16.921
# 		test loss: 43.220, test rec: 26.423, test kl: 16.797

# %%
image = test_set[71][0].unsqueeze(0)

# %%
plt.imshow((image.squeeze() + 1) / 2, cmap='gray')

# %%
vae = vae.to('cpu')
noisy = True

with torch.no_grad():
    z_mu, z_log_sigma_sq = vae.encode(image)
    eps = torch.randn_like(z_mu) if noisy else torch.zeros_like(z_mu)

    z = vae.reparameterize(z_mu, z_log_sigma_sq, eps)
    rec_image = vae.decode(z)

# %%
plt.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')

# %% [markdown]
# Unconditional sampling (from standard normal -- prior for latents)

# %%
z_mu, z_log_sigma_sq = vae.encode(image)
fig, axs = plt.subplots(2, 3, figsize=(9, 6))
plt.tight_layout()

for ax in axs.flatten():
    with torch.no_grad():
        z = torch.randn_like(z_mu)
        rec_image = vae.decode(z)

    ax.imshow((rec_image[0, 0] + 1) / 2, cmap='gray')

plt.show()

# %% [markdown]
# Conditional sampling (from latents posterior)

# %%
z_mu, z_log_sigma_sq = vae.encode(image)
fig, axs = plt.subplots(2, 3, figsize=(9, 6))
plt.tight_layout()

for ax in axs.flatten():
    with torch.no_grad():
        eps = torch.randn_like(z_mu)
        z = vae.reparameterize(z_mu, z_log_sigma_sq, eps)
        rec_image = vae.decode(z)

    ax.imshow((rec_image[0, 0] + 1) / 2, cmap='gray')

plt.show()

# %%
ae_latents = []

ae = ae.to(device)
with torch.inference_mode():
    for images, _ in tqdm(test_loader, desc=f'Generating latents'):
        images = images.to(device)
        latents = ae.encode(images)
        ae_latents.append(latents.cpu())

ae_latents = torch.cat(ae_latents, dim=0).squeeze().numpy()
# Out:
# Generating latents:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
vae_latents = []
vae_log_sigma_sq = []

vae = vae.to(device)
with torch.inference_mode():
    for images, _ in tqdm(test_loader, desc=f'Generating latents'):
        images = images.to(device)
        latents, log_sigma_sq = vae.encode(images)
        vae_latents.append(latents.cpu())
        vae_log_sigma_sq.append(log_sigma_sq.cpu())

vae_latents = torch.cat(vae_latents, dim=0).squeeze().numpy()
vae_log_sigma_sq = torch.cat(vae_log_sigma_sq, dim=0).squeeze().numpy()
# Out:
# Generating latents:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
from sklearn.manifold import TSNE
import seaborn as sns

# %%
ae_embeds = TSNE(verbose=2).fit_transform(ae_latents)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.002s...
# [t-SNE] Computed neighbors for 10000 samples in 0.283s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.878562
# [t-SNE] Computed conditional probabilities in 0.081s
# [t-SNE] Iteration 50: error = 88.9675064, gradient norm = 0.0143881 (50 iterations in 0.440s)
# [t-SNE] Iteration 100: error = 83.1821976, gradient norm = 0.0030431 (50 iterations in 0.323s)
# [t-SNE] Iteration 150: error = 82.2061005, gradient norm = 0.0012168 (50 iterations in 0.316s)
# [t-SNE] Iteration 200: error = 81.8957520, gradient norm = 0.0007012 (50 iterations in 0.315s)
# [t-SNE] Iteration 250: error = 81.7685852, gradient norm = 0.0004990 (50 iterations in 0.313s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.768585
# [t-SNE] Iteration 300: error = 2.8446481, gradient norm = 0.0124535 (50 iterations in 0.285s)
# [t-SNE] Iteration 350: error = 2.3606553, gradient norm = 0.0105723 (50 iterations in 0.273s)
# [t-SNE] Iteration 400: error = 2.1430118, gradient norm = 0.0094312 (50 iterations in 0.270s)
# [t-SNE] Iteration 450: error = 2.0141737, gradient norm = 0.0087312 (50 iterations in 0.271s)
# [t-SNE] Iteration 500: error = 1.9274931, gradient norm = 0.0081351 (50 iterations in 0.269s)
# [t-SNE] Iteration 550: error = 1.8654426, gradient norm = 0.0076435 (50 iterations in 0.269s)
# [t-SNE] Iteration 600: error = 1.8189218, gradient norm = 0.0072450 (50 iterations in 0.269s)
# [t-SNE] Iteration 650: error = 1.7830740, gradient norm = 0.0067237 (50 iterations in 0.270s)
# [t-SNE] Iteration 700: error = 1.7551862, gradient norm = 0.0062329 (50 iterations in 0.271s)
# [t-SNE] Iteration 750: error = 1.7327878, gradient norm = 0.0057866 (50 iterations in 0.269s)
# [t-SNE] Iteration 800: error = 1.7149405, gradient norm = 0.0052625 (50 iterations in 0.271s)
# [t-SNE] Iteration 850: error = 1.7005690, gradient norm = 0.0047847 (50 iterations in 0.272s)
# [t-SNE] Iteration 900: error = 1.6889293, gradient norm = 0.0043171 (50 iterations in 0.272s)
# [t-SNE] Iteration 950: error = 1.6792934, gradient norm = 0.0038533 (50 iterations in 0.273s)
# [t-SNE] Iteration 1000: error = 1.6717753, gradient norm = 0.0033554 (50 iterations in 0.271s)
# [t-SNE] KL divergence after 1000 iterations: 1.671775

# %%
plt.figure(figsize=(8, 8))
colors = sns.color_palette('hls', 10)
targets = test_set.targets.numpy()

for i, color in enumerate(colors):
    plt.scatter(ae_embeds[targets == i, 0], ae_embeds[targets == i, 1], color=color, label=str(i))

plt.legend()

# %%
vae_embeds = TSNE(verbose=2).fit_transform(vae_latents)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.002s...
# [t-SNE] Computed neighbors for 10000 samples in 0.182s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.917708
# [t-SNE] Computed conditional probabilities in 0.076s
# [t-SNE] Iteration 50: error = 91.5192337, gradient norm = 0.0193062 (50 iterations in 0.658s)
# [t-SNE] Iteration 100: error = 85.3918152, gradient norm = 0.0023464 (50 iterations in 0.448s)
# [t-SNE] Iteration 150: error = 84.6264114, gradient norm = 0.0010750 (50 iterations in 0.449s)
# [t-SNE] Iteration 200: error = 84.3992004, gradient norm = 0.0007675 (50 iterations in 0.447s)
# [t-SNE] Iteration 250: error = 84.3157196, gradient norm = 0.0006040 (50 iterations in 0.451s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 84.315720
# [t-SNE] Iteration 300: error = 3.0091999, gradient norm = 0.0120565 (50 iterations in 0.312s)
# [t-SNE] Iteration 350: error = 2.5509470, gradient norm = 0.0102338 (50 iterations in 0.279s)
# [t-SNE] Iteration 400: error = 2.3416603, gradient norm = 0.0092466 (50 iterations in 0.278s)
# [t-SNE] Iteration 450: error = 2.2156737, gradient norm = 0.0086177 (50 iterations in 0.277s)
# [t-SNE] Iteration 500: error = 2.1303673, gradient norm = 0.0080493 (50 iterations in 0.277s)
# [t-SNE] Iteration 550: error = 2.0688019, gradient norm = 0.0075733 (50 iterations in 0.278s)
# [t-SNE] Iteration 600: error = 2.0226536, gradient norm = 0.0071063 (50 iterations in 0.278s)
# [t-SNE] Iteration 650: error = 1.9870791, gradient norm = 0.0066930 (50 iterations in 0.279s)
# [t-SNE] Iteration 700: error = 1.9589658, gradient norm = 0.0062732 (50 iterations in 0.279s)
# [t-SNE] Iteration 750: error = 1.9366000, gradient norm = 0.0057342 (50 iterations in 0.282s)
# [t-SNE] Iteration 800: error = 1.9186640, gradient norm = 0.0052012 (50 iterations in 0.280s)
# [t-SNE] Iteration 850: error = 1.9041251, gradient norm = 0.0048421 (50 iterations in 0.280s)
# [t-SNE] Iteration 900: error = 1.8919392, gradient norm = 0.0045298 (50 iterations in 0.281s)
# [t-SNE] Iteration 950: error = 1.8817723, gradient norm = 0.0040269 (50 iterations in 0.281s)
# [t-SNE] Iteration 1000: error = 1.8734262, gradient norm = 0.0035905 (50 iterations in 0.282s)
# [t-SNE] KL divergence after 1000 iterations: 1.873426

# %%
plt.figure(figsize=(8, 8))
colors = sns.color_palette('hls', 10)
targets = test_set.targets.numpy()

for i, color in enumerate(colors):
    plt.scatter(vae_embeds[targets == i, 0], vae_embeds[targets == i, 1], color=color, label=str(i))

plt.legend()

# %%
i = 4

z_mu = torch.from_numpy(vae_latents[targets == i].mean(0).reshape(1, -1, 1, 1))
z_log_sigma_sq = torch.from_numpy(np.log(vae_latents[targets == i].var(0).reshape(1, -1, 1, 1)))

fig, axs = plt.subplots(2, 3, figsize=(9, 6))
plt.tight_layout()

vae = vae.to('cpu')
for ax in axs.flatten():
    with torch.no_grad():
        eps = torch.randn_like(z_mu)
        z = vae.reparameterize(z_mu, z_log_sigma_sq, eps)
        rec_image = vae.decode(z)

    ax.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')

plt.show()

# %%
# z_log_sigma_sq = torch.from_numpy(np.log(vae_latents[targets == i].var(0).reshape(1, -1, 1, 1)))

fig, axs = plt.subplots(2, 5, figsize=(10, 4))
plt.tight_layout()
plt.subplots_adjust(wspace=0.05, hspace=0.1)

vae = vae.to('cpu')
for i, ax in enumerate(axs.flatten()):
    z_mu = torch.from_numpy(vae_latents[targets == i].mean(0).reshape(1, -1, 1, 1))
    with torch.no_grad():
        # eps = torch.randn_like(z_mu)
        # z = vae.reparameterize(z_mu, z_log_sigma_sq, eps)
        rec_image = vae.decode(z_mu)

    ax.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')
    ax.axis("off")

plt.show()

# %% [markdown]
# ### Interpolate

# %%
image1, image2 = test_set[73][0].unsqueeze(0), test_set[77][0].unsqueeze(0)

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))

axs[0].imshow((image1.squeeze() + 1) / 2, cmap='gray')
axs[1].imshow((image2.squeeze() + 1) / 2, cmap='gray')

# %%
z_mu1, _ = vae.encode(image1)
z_mu2, _ = vae.encode(image2)

alphas = np.linspace(0, 1, 15)
images = []

with torch.inference_mode():
    for alpha in alphas:
        z_mu = z_mu1 * (1 - alpha) + z_mu2 * alpha
        rec_image = vae.decode(z_mu)
        images.append(rec_image)

# %%
fig, axs = plt.subplots(3, 5, figsize=(10, 6))

for rec_image, ax in zip(images, axs.flatten()):
    ax.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')
    ax.axis('off')

# %%
z_latent1 = ae.encode(image1.to(device))
z_latent2 = ae.encode(image2.to(device))

alphas = np.linspace(0, 1, 15)
images = []

with torch.inference_mode():
    for alpha in alphas:
        z_latent = z_latent1 * (1 - alpha) + z_latent2 * alpha
        rec_image = ae.decode(z_latent)
        images.append(rec_image.cpu().numpy())

# %%
fig, axs = plt.subplots(3, 5, figsize=(10, 6))

for rec_image, ax in zip(images, axs.flatten()):
    ax.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')
    ax.axis('off')

# %% [markdown]
# ### Out of distribution

# %%
plt.tight_layout()

vae = vae.to('cpu')
with torch.no_grad():
    z_mu = torch.randn_like(z_mu) * 100000000
    eps = torch.randn_like(z_mu)
    z = vae.reparameterize(z_mu, z_log_sigma_sq, eps)
    rec_image = vae.decode(z_mu)

plt.imshow((rec_image.squeeze() + 1) / 2, cmap='gray')

plt.show()
